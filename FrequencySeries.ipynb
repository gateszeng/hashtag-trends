# %%
import numpy as np
import pandas as pd

# %%
# generate time series df with popularity rating
datasetname = "falcon9--2018-02-01--2019-07-01.csv"
filepath = "./datasets/" + datasetname

# %%
def getFrequency(dataset_name):
    filepath = "./datasets/" + datasetname
    
    dataset_df = pd.read_csv(filepath)
    params = dataset_name[:-4].split('--')
    date_df = pd.Series(0, index=pd.date_range(params[1], params[2]))
    
    filtered_dates = dataset_df.loc[:, ['date']]
    filtered_dates = filtered_dates.apply(lambda x: pd.to_datetime(x).dt.normalize())    
    counts = filtered_dates.groupby('date').size()
    
    # merge dates and counts, so that we have all dates
    counts = (counts + date_df).fillna(0)

    return dataset_df, counts

def normalizeFrequency(freqs):
    # min-max feature scaling to get values between 0 and 1
    freqs_norm = (freqs - freqs.min()) / (freqs.max() - freqs.min())
    return freqs_norm

def getTopPostFromDate(dataset_df, date):
    # grab tweets from most active day
    data_df.loc[:, 'date'] = data_df.loc[:, 'date'].apply(lambda x: pd.to_datetime(x).normalize())
    top_df = data_df.groupby(by='date').get_group(pd.Timestamp(2019,5,24))
    
    top_df = top_df.sort_values('favorites', ascending=False)
    
    return top_df

# %%
# display frequency of dataset
data_df, freqs = getFrequency(datasetname)
freqs
# Out:
# 2018-01-31    0.0
# 2018-02-01    2.0
# 2018-02-02    2.0
# 2018-02-03    0.0
# 2018-02-04    0.0
# 2018-02-05    0.0
# 2018-02-06    6.0
# 2018-02-07    1.0
# 2018-02-08    1.0
# 2018-02-09    1.0
# 2018-02-10    0.0
# 2018-02-11    0.0
# 2018-02-12    0.0
# 2018-02-13    0.0
# 2018-02-14    0.0
# 2018-02-15    0.0
# 2018-02-16    0.0
# 2018-02-17    0.0
# 2018-02-18    0.0
# 2018-02-19    0.0
# 2018-02-20    0.0
# 2018-02-21    0.0
# 2018-02-22    2.0
# 2018-02-23    0.0
# 2018-02-24    0.0
# 2018-02-25    0.0
# 2018-02-26    1.0
# 2018-02-27    0.0
# 2018-02-28    1.0
# 2018-03-01    0.0
#              ...
# 2019-06-02    0.0
# 2019-06-03    0.0
# 2019-06-04    0.0
# 2019-06-05    0.0
# 2019-06-06    0.0
# 2019-06-07    0.0
# 2019-06-08    0.0
# 2019-06-09    0.0
# 2019-06-10    0.0
# 2019-06-11    0.0
# 2019-06-12    0.0
# 2019-06-13    0.0
# 2019-06-14    0.0
# 2019-06-15    0.0
# 2019-06-16    0.0
# 2019-06-17    0.0
# 2019-06-18    0.0
# 2019-06-19    0.0
# 2019-06-20    0.0
# 2019-06-21    0.0
# 2019-06-22    0.0
# 2019-06-23    0.0
# 2019-06-24    0.0
# 2019-06-25    0.0
# 2019-06-26    0.0
# 2019-06-27    0.0
# 2019-06-28    0.0
# 2019-06-29    0.0
# 2019-06-30    0.0
# 2019-07-01    0.0
# Length: 517, dtype: float64

# %%
# display normalized frequency
freqs_norm = normalizeFrequency(freqs)
freqs_norm
# Out:
# 2018-01-31    0.000000
# 2018-02-01    0.014184
# 2018-02-02    0.014184
# 2018-02-03    0.000000
# 2018-02-04    0.000000
# 2018-02-05    0.000000
# 2018-02-06    0.042553
# 2018-02-07    0.007092
# 2018-02-08    0.007092
# 2018-02-09    0.007092
# 2018-02-10    0.000000
# 2018-02-11    0.000000
# 2018-02-12    0.000000
# 2018-02-13    0.000000
# 2018-02-14    0.000000
# 2018-02-15    0.000000
# 2018-02-16    0.000000
# 2018-02-17    0.000000
# 2018-02-18    0.000000
# 2018-02-19    0.000000
# 2018-02-20    0.000000
# 2018-02-21    0.000000
# 2018-02-22    0.014184
# 2018-02-23    0.000000
# 2018-02-24    0.000000
# 2018-02-25    0.000000
# 2018-02-26    0.007092
# 2018-02-27    0.000000
# 2018-02-28    0.007092
# 2018-03-01    0.000000
#                 ...
# 2019-06-02    0.000000
# 2019-06-03    0.000000
# 2019-06-04    0.000000
# 2019-06-05    0.000000
# 2019-06-06    0.000000
# 2019-06-07    0.000000
# 2019-06-08    0.000000
# 2019-06-09    0.000000
# 2019-06-10    0.000000
# 2019-06-11    0.000000
# 2019-06-12    0.000000
# 2019-06-13    0.000000
# 2019-06-14    0.000000
# 2019-06-15    0.000000
# 2019-06-16    0.000000
# 2019-06-17    0.000000
# 2019-06-18    0.000000
# 2019-06-19    0.000000
# 2019-06-20    0.000000
# 2019-06-21    0.000000
# 2019-06-22    0.000000
# 2019-06-23    0.000000
# 2019-06-24    0.000000
# 2019-06-25    0.000000
# 2019-06-26    0.000000
# 2019-06-27    0.000000
# 2019-06-28    0.000000
# 2019-06-29    0.000000
# 2019-06-30    0.000000
# 2019-07-01    0.000000
# Length: 517, dtype: float64

# %%
# display most active day
print("Day with most Tweets: %s, %d" % (str(freqs.idxmax()), freqs.max()))

# get most popular tweets from that day
getTopPostFromDate(data_df, freqs.idxmax())
# Out:
# Day with most Tweets: 2019-05-23 00:00:00, 141
#                        username      user_handle       date  retweets  \
# 4                Michael Baylor  nextspaceflight 2019-05-24       307
# 3       Dr.DahaNoob (Denise K.)         Mimikry_ 2019-05-24        34
# 22                  Erik Kuna 🚀         erikkuna 2019-05-24        26
# 11                  Marcus Cote  marcuscotephoto 2019-05-24        22
# 10                🗣Eric DeSalvo      EricDeSalvo 2019-05-24         6
# 8                       Richard     RDAnglePhoto 2019-05-24        35
# 9                   Flight Club     flightclubio 2019-05-24        13
# 2                Diana Halstead    DianaHalstead 2019-05-24         9
# 6              Thomas Burghardt      TGMetsFan98 2019-05-24         5
# 7                    LaunchLife   YourLaunchLife 2019-05-24         3
# 5                 Lyfe B. Wilde  ArrogantWatcher 2019-05-24         6
# 59          Katya Pavlushchenko      katlinegrey 2019-05-24         1
# 23                      Altaira    JrAstronautin 2019-05-24         3
# 41  The Talk of Titusville 🚀🌴🌎🌕     TalkofTville 2019-05-24         0
#
#     favorites                                               text  \
# 4        1267  #Starlink passes over the Netherlands after la...
# 3         240  Finally here my clean shot from yesterdays #Sp...
# 22        182  Ever wonder what it would look like to watch a...
# 11        171  Through the lightning tower-- #Falcon9 lifts f...
# 10        139  Blastoff views from the heart of Orlando #Falc...
# 8         124  My views of last nights @SpaceX #Falcon9 launc...
# 9          57  My #Falcon9 S2 model is underpowered It was al...
# 2          53  Success! @SpaceX Falcon9 Starlink! #SpaceX #Fa...
# 6          32  Replay: @SpaceX #Falcon9 launches the first 60...
# 7          27  We’ll be doing a blog post of your Starlink la...
# 5          24  THE SPACE COAST #Falcon9 @spacex pic.twitter.c...
# 59         19  Well, and of course #Rogozin couldn't resist t...
# 23         13  We have LIFTOFF! GO #Falcon9! Go #Starlink! ht...
# 41          2  @SpaceX #Falcon9 fairings successfully recover...
#
#     geological_location                                   mentions  \
# 4                   NaN                                @jelhoo1bf4
# 3                   NaN                                        NaN
# 22                  NaN  @erikkuna @superclusterhq @superclusterhq
# 11                  NaN                           @marcuscotephoto
# 10                  NaN                                        NaN
# 8                   NaN                          @SpaceX @elonmusk
# 9                   NaN           @Erdayastronaut @elonmusk @934kN
# 2                   NaN                                    @SpaceX
# 6                   NaN                                    @SpaceX
# 7                   NaN                                        NaN
# 5                   NaN                                    @spacex
# 59                  NaN                                  @elonmusk
# 23                  NaN                                        NaN
# 41                  NaN                                    @SpaceX
#
#                                         hashtags             tweet_id  \
# 4                     #Starlink #SpaceX #Falcon9  1132073019071877120
# 3                     #SpaceX #Falcon9 #Starlink  1132092811489230848
# 22          #SpaceX #Falcon9 #spaceisforeveryone  1132043762572636161
# 11            #Falcon9 #OCISLY #Starlink #SpaceX  1131913831440146434
# 10                                      #Falcon9  1131947137091162112
# 8                     #Falcon9 #Starlink #SpaceX  1131976440952565761
# 9                             #Falcon9 #Starlink  1131970182640013312
# 2   #SpaceX #Falcon9 #Starlink #NASA #NASASocial  1132122553647083521
# 6                             #Falcon9 #Starlink  1132016434152919047
# 7                 #falcon9 #starlink #launchlife  1131986653747134464
# 5                                       #Falcon9  1132059522485432321
# 59                             #Rogozin #Falcon9  1131838010415300608
# 23                            #Falcon9 #Starlink  1131852656773873664
# 41                            #Falcon9 #StarLink  1132005217229266945
#
#                                             permalink
# 4   https://twitter.com/nextspaceflight/status/113...
# 3   https://twitter.com/Mimikry_/status/1132092811...
# 22  https://twitter.com/erikkuna/status/1132043762...
# 11  https://twitter.com/marcuscotephoto/status/113...
# 10  https://twitter.com/EricDeSalvo/status/1131947...
# 8   https://twitter.com/RDAnglePhoto/status/113197...
# 9   https://twitter.com/flightclubio/status/113197...
# 2   https://twitter.com/DianaHalstead/status/11321...
# 6   https://twitter.com/TGMetsFan98/status/1132016...
# 7   https://twitter.com/YourLaunchLife/status/1131...
# 5   https://twitter.com/ArrogantWatcher/status/113...
# 59  https://twitter.com/katlinegrey/status/1131838...
# 23  https://twitter.com/JrAstronautin/status/11318...
# 41  https://twitter.com/TalkofTville/status/113200...
