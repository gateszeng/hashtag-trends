# %%
from WeiCheng_py_file.word_freq import *

# %% [markdown]
# ### Drawing bar chat of #Falconheavy

# %%
directory_spacex=  "Twitter-Get-Old-Tweets-Scraper/Spacex"
word_dict_spacex = get_freq_words_topic(n=11, directory = directory_spacex)
freq_words_spacex = list(word_dict_spacex.keys())[1:]
draw_bars(directory_spacex, "SpaceX", freq_words_spacex)
# Out:
# finished file falcon9--2018-02-01--2019-07-01.csv >> 596 lines (596)
# finished file tesla--2018-02-01--2019-07-01.csv >> 6583 lines (5987)
# finished file spacex--2018-02-01--2019-07-01.csv >> 9334 lines (2751)
# finished file falconheavy--2018-02-01--2019-07-01.csv >> 10872 lines (1538)
# finished file elonmusk--2018-02-01--2019-07-01.csv >> 12373 lines (1501)
# finished file Twitter-Get-Old-Tweets-Scraper/Spacex/falcon9--2018-02-01--2019-07-01.csv >> 596 lines (596)
# finished file Twitter-Get-Old-Tweets-Scraper/Spacex/tesla--2018-02-01--2019-07-01.csv >> 5992 lines (5992)
# finished file Twitter-Get-Old-Tweets-Scraper/Spacex/spacex--2018-02-01--2019-07-01.csv >> 3074 lines (3074)
# finished file Twitter-Get-Old-Tweets-Scraper/Spacex/falconheavy--2018-02-01--2019-07-01.csv >> 1961 lines (1961)
# finished file Twitter-Get-Old-Tweets-Scraper/Spacex/elonmusk--2018-02-01--2019-07-01.csv >> 1981 lines (1981)

# %% [markdown]
# ### Draw bar chart of #Parkland

# %%
directory=  "Twitter-Get-Old-Tweets-Scraper/gunshoot"
word_dict= get_freq_words_topic(n=11, directory =directory )
print(list(word_dict.keys()))
freq_words = list(word_dict.keys())[1:]
print(freq_words)
draw_bars(directory, "Gunshoot",freq_words)
# Out:
# finished file neveragain--2018-01-29--2018-08-14.csv >> 10120 lines (10120)
# finished file parkland--2018-01-29--2018-08-14.csv >> 12835 lines (2715)
# finished file marchforourlives--2018-01-29--2018-08-14.csv >> 13270 lines (435)
# finished file gunreformnow--2018-01-29--2018-08-14.csv >> 16554 lines (3284)
# finished file guncontrolnow--2018-01-29--2018-08-14.csv >> 20173 lines (3619)
# ['…', 'gun', 'school', 'students', 'people', 'nra', 'kids', 'need', 'us', 'one', 'like']
# ['gun', 'school', 'students', 'people', 'nra', 'kids', 'need', 'us', 'one', 'like']
# finished file Twitter-Get-Old-Tweets-Scraper/gunshoot/neveragain--2018-01-29--2018-08-14.csv >> 10120 lines (10120)
# finished file Twitter-Get-Old-Tweets-Scraper/gunshoot/parkland--2018-01-29--2018-08-14.csv >> 2945 lines (2945)
# finished file Twitter-Get-Old-Tweets-Scraper/gunshoot/marchforourlives--2018-01-29--2018-08-14.csv >> 500 lines (500)
# ...

# %% [markdown]
# ### Generating wordcloud of #Parkland

# %%
directory = 'Twitter-Get-Old-Tweets-Scraper/Gunshoot'
file_names = os.listdir(directory)
if 'mergedfile.csv' in file_names:
    file_names.remove('mergedfile.csv')
if '.DS_Store' in file_names:  
    file_names.remove('.DS_Store')
#print("file_names:", file_names)
mask = np.array(Image.open("cloud.jpeg"))
for filename in file_names:
    filename = directory + '/'+ filename
    save_wordcloud(filename,mask)

# %%
directory = 'Twitter-Get-Old-Tweets-Scraper/Spacex'
file_names = os.listdir(directory)
if 'mergedfile.csv' in file_names:
    file_names.remove('mergedfile.csv')
if '.DS_Store' in file_names:  
    file_names.remove('.DS_Store')
#print("file_names:", file_names)
mask = np.array(Image.open("cloud.jpeg"))
for filename in file_names:
    filename = directory + '/'+ filename
    save_wordcloud(filename,mask)
